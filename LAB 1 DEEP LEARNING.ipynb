# %% [markdown]
# # import  the libaries

# %%
import tensorflow as tf
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# # load the data set

# %%
from keras.datasets import mnist
objects=mnist
(train_img,train_lab),(test_img,test_lab)=objects.load_data()

# %% [markdown]
# # displaying th first 20  images of the training set

# %%
for i in range(20):
 plt.subplot(5,4,i+1)
 plt.imshow(train_img[i],cmap='gray_r')
 plt.title("Digit:{}".format(train_lab[i]))
 plt.subplots_adjust(hspace=0.5)
 plt.axis('off')

# %%
plt.hist(train_img[0].reshape(784),facecolor='green')
plt.title('pixel Vs Its intensity',fontsize=20)
plt.Ylable=('pixel')
plt.Xlabel=('intensity')
plt.text(0.5,0,'intensity')
# Out:
# Text(0.5, 0, 'intensity')

# %% [markdown]
# # preprocessing the data

# %%
train_img=train_img/255.0
test_img=test_img/255.0

# %% [markdown]
# # After normalization

# %%
plt.hist(train_img[0].reshape(784),facecolor='green')
plt.title('pixel Vs Its intensity',fontsize=20)
plt.Ylable=('pixel')
plt.Xlabel=('intensity')
plt.text(0.5,0,'intensity')
# Out:
# Text(0.5, 0, 'intensity')

# %% [markdown]
# # creating the model

# %%
from keras.models import Sequential
from keras.layers import Flatten,Dense
model=Sequential()
input_layer=Flatten(input_shape=(28,28))
model.add (input_layer)
hidden_layer1=Dense(512,activation='relu')
model.add(hidden_layer1)
hidden_layer2=Dense(512,activation='relu')
model.add(hidden_layer2)
output_layer=Dense(10,activation='softmax')
model.add(output_layer)

# %% [markdown]
# # compiling the model

# %%
model.compile(optimizer ='adam',loss = 'sparse_categorical_crossentropy',metrics = ['accuracy'])

# %% [markdown]
# # train the model

# %%
model.fit(train_img,train_lab,epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 25s 12ms/step - loss: 0.1836 - accuracy: 0.9443
# Epoch 2/5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0802 - accuracy: 0.9748
# Epoch 3/5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0557 - accuracy: 0.9819
# Epoch 4/5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0423 - accuracy: 0.9865
# Epoch 5/5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0347 - accuracy: 0.9890

# %% [markdown]
# # evaluate the model

# %%
loss_and_acc=model.evaluate(test_img,test_lab,verbose=2)    
print("test loss",loss_and_acc[0])
print("test accuracy",loss_and_acc[1])
# Out:
# 313/313 - 2s - loss: 0.0642 - accuracy: 0.9825 - 2s/epoch - 6ms/step
# test loss 0.0641624927520752
# test accuracy 0.9825000166893005
